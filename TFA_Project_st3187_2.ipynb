# %%
#importing review text and label files to dataframe

import pandas as pd

df_test_text = pd.read_table('imdb_test_text.txt', delim_whitespace=False, names=('A'))
df_test_labels = pd.read_table('imdb_test_labels.txt', delim_whitespace=False, names=('B'))

# %%
#merging them on index
df_test=df_test_text.join(df_test_labels, how='outer')
# df_test

# %%
#changing column name
df_test=df_test.rename(columns={'A':'review_text',
                          'B':'review_label'})
df_test.index.name='S.No.'
# df_test

# %%
df_train_text = pd.read_table('imdb_train_text.txt', delim_whitespace=False, names=('A'))
df_train_labels = pd.read_table('imdb_train_labels.txt', delim_whitespace=False, names=('B'))

# %%
#merging them on index
df_train=df_train_text.join(df_train_labels, how='outer')

# %%
#changing column name
df_train=df_train.rename(columns={'A':'review_text',
                          'B':'review_label'})
df_train.index.name='S.No.'
# df_train

# %%
frames=[df_train, df_test] # concatenating the training and testing datasets
df_total=pd.concat(frames)
# df_total

# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas, xgboost, numpy, string

# %%
trainDF=pd.DataFrame()
trainDF['text']=df_train['review_text']
trainDF['label']=df_train['review_label']
# trainDF

# %%
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'])

# label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

# %%
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
count_vect.fit(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xvalid_count =  count_vect.transform(valid_x)

# %%
# word level tf-idf
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(trainDF['text'])
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# ngram level tf-idf 
tfidf_vect_ngram = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram.fit(trainDF['text'])
xtrain_tfidf_ngram =  tfidf_vect_ngram.transform(train_x)
xvalid_tfidf_ngram =  tfidf_vect_ngram.transform(valid_x)

# characters level tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(trainDF['text'])
xtrain_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(train_x) 
xvalid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(valid_x)

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    #return predictions
    
return metrics.accuracy_score(predictions, valid_y)

# %%
# Extereme Gradient Boosting on Count Vectors
accuracy_cv = train_model(xgboost.XGBClassifier(), xtrain_count.tocsc(), train_y, xvalid_count.tocsc())
print ("Xgb, Count Vectors: ", accuracy_cv)
# Out:
# Xgb, Count Vectors:  [7 5 0 ... 0 1 5]
# C:\Users\Somanath\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# Extereme Gradient Boosting on Word Level TF IDF Vectors
accuracy_tf = train_model(xgboost.XGBClassifier(), xtrain_tfidf.tocsc(), train_y, xvalid_tfidf.tocsc())
print ("Xgb, WordLevel TF-IDF: ", accuracy_tf)

# Extereme Gradient Boosting on Character Level TF IDF Vectors
accuracy_char = train_model(xgboost.XGBClassifier(), xtrain_tfidf_ngram_chars.tocsc(), train_y, xvalid_tfidf_ngram_chars.tocsc())
print ("Xgb, CharLevel Vectors: ", accuracy_char)
# Out:
# C:\Users\Somanath\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Xgb, WordLevel TF-IDF:  [7 7 0 ... 0 1 5]
# Xgb, CharLevel Vectors:  [7 6 0 ... 0 5 4]
# C:\Users\Somanath\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
d = {'valid_review': valid_x, 'valid_label': valid_y, 'predicted': accuracy_tf}
df_pred = pd.DataFrame(data=d)
df_pred['predicted'].unique()
df_pred['accuracy']=df_pred['valid_label']-df_pred['predicted']
df_pred['accuracy']=df_pred['accuracy'].abs()
df_pred['accuracy'].mean()
# Out:
# 1.676

# %%
df_pred
# Out:
#                                             valid_review  valid_label  \
# S.No.
# 8202   A heartwarming film. The usual superb acting b...            7
# 8937   Yes, I call this a perfect movie. Not one bori...            7
# 23736  This movie was crap with a capital "C." The op...            1
# 11255  I had the privilege of watching "Holly" at the...            7
# 21726  Sorry Fulci fans, but I could not get through ...            0
# 6370   So Mary and Rhoda have aged--who hasn't? I was...            4
# 1738   Apart from the usual stereotypes of the thirti...            7
# 4101   Those engaging the movie camera so early in th...            4
# 19345  I'm not a big fan of rom/coms at the best of t...            3
# 657    This "tragicomedy" written by famous Serbian t...            7
# 5023   I don't know why I picked this movie to watch,...            5
# 2514   Well, this was one of those films I caught on ...            5
# 14762  A splendid example of how Hollywood could (and...            0
# 15324  Oh, well, this movie starts off well. It's kin...            3
# 12053  Like many people on this site, I saw this movi...            5
# 17666  Although I have to admit I laughed more watchi...            0
# 3429   What can I say, it's a damn good movie. See it...            7
# 19559  This has to be the worst movie I have seen. Ma...            0
# 3244   1991 saw the release of the two best sequels o...            7
# 18635  Just okay horror film about a nice suburban fa...            3
# 6285   Emma was a product of what might be called by ...            4
# 21069  I had not seen the movie trailer when I went t...            3
# 99     It sounds a bit awkward to call a film about w...            7
# 2138   This movie works because it feels so genuine. ...            7
# 16039  This is simply put, the worst movie I have eve...            0
# 12926  Unless I'm sadly mistaken, I rented A Nightmar...            3
# 23501  OK, anyone who could honestly say that this mo...            0
# 17441  Watching this last night it amazed me that Fox...            3
# 22762  This is a horrible little film--and unfortunat...            0
# 10546  This time around, Blackadder is no longer roya...            4
# ...                                                  ...          ...
# 15636  Any movie in which Brooke Shields out-acts a F...            1
# 22083  Average (and surprisingly tame) Fulci giallo w...            2
# 4053   This is very much not the sort of movie for wh...            6
# 7194   Bogdonovich's (mostly) unheralded classic is a...            7
# 17001  This Movie is complete crap! Avoid this waste ...            0
# 14577  The concept for Sarafina appears to be a sound...            2
# 10931  I so love this movie! The animation is great (...            7
# 12856  The first half of this version was the best I'...            3
# 23091  Ghost of Dragstrip Hollow was one of the many ...            3
# 23534  Well, I just ordered this on my pay-per-view a...            2
# 24932  The plot sounds vaguely interesting ... a scie...            1
# 4208   A must see movie for anyone who ever went to c...            7
# 5197   2005 Toronto Film Festival Report It is offici...            4
# 678    A series of vignettes, most of them spoofing t...            5
# 19188  One of the worst movies I've ever seen with Ro...            1
# 3759   This is a very intriguing short movie by David...            5
# 14593  Let me start by saying that I'd read a number ...            1
# 8665   There are people claiming this is another "bad...            6
# 13441  Ha. without a doubt Tommy's the evil one here....            3
# 8646   Descent. Yeah. Boy... I haven't seen anything ...            6
# 591    <br /><br />I just bought this movie on DVD an...            4
# 10431  I have always been a fan of the show so I'll a...            6
# 24055  Everyone else who has commented negatively abo...            0
# 10407  Fortunately for us Real McCoy fans (most likel...            5
# 14879  Pointless short about a bunch of half naked me...            0
# 23083  TOM BROWN'S SCHOOLDAYS <br /><br />Aspect rati...            3
# 3038   the movie is great, like every other internati...            5
# 14318  Despite being a 2001 movie, the direction is t...            3
# 866    Where the Sidewalk Ends (1950)<br /><br />Wher...            7
# 3696   Not since The Simpsons made it's debut has the...            5
#
#        predicted  accuracy
# S.No.
# 8202           7         0
# 8937           7         0
# 23736          0         1
# 11255          7         0
# 21726          0         0
# 6370           7         3
# 1738           7         0
# 4101           3         1
# 19345          7         4
# 657            7         0
# 5023           7         2
# 2514           0         5
# 14762          3         3
# 15324          7         4
# 12053          7         2
# 17666          0         0
# 3429           7         0
# 19559          0         0
# 3244           1         6
# 18635          7         4
# 6285           4         0
# 21069          3         0
# 99             7         0
# 2138           7         0
# 16039          0         0
# 12926          3         0
# 23501          7         7
# 17441          0         3
# 22762          0         0
# 10546          4         0
# ...          ...       ...
# 15636          0         1
# 22083          2         0
# 4053           5         1
# 7194           7         0
# 17001          0         0
# 14577          2         0
# 10931          7         0
# 12856          7         4
# 23091          7         4
# 23534          2         0
# 24932          0         1
# 4208           7         0
# 5197           5         1
# 678            7         2
# 19188          0         1
# 3759           7         2
# 14593          0         1
# 8665           0         6
# 13441          3         0
# 8646           7         1
# 591            4         0
# 10431          7         1
# 24055          7         7
# 10407          7         2
# 14879          0         0
# 23083          7         4
# 3038           7         2
# 14318          0         3
# 866            1         6
# 3696           5         0
#
# [6250 rows x 4 columns]
